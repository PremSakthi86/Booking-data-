# %% [markdown]
# ## DATA ANALYSIS PROJECT

# %%
import pandas as pd 
import numpy as np

# %%
df =  pd.read_csv('DataAnalyst.csv',encoding_errors='ignore')
df
# Out:
#                                Booking ID  \
# 0    279d92c6-ce26-47c0-8915-e45b77fe20e2
# 1    415bfcbe-1a2e-4d4b-809a-4c5b606653b1
# 2    2100024b-46fc-47b5-ac1c-047d007a4723
# 3    74936def-088f-4d34-bad1-dfa76f78b704
# 4    6272b4e7-a508-4ed7-bae0-21f7293287a8
# ..                                    ...
# 995  b45c041f-6199-4a53-8841-1afd696d8c2d
# 996  633d1590-d9b2-4263-9b29-8589333c7a0a
# 997  c552c1b5-bb2e-46a5-b5c9-43101cf39133
# 998  09fb0473-56cc-4624-9c5a-e9cd152acc41
# 999  552b1c51-61e3-4005-a57c-ff953a2c87b7
#
#                               Customer ID  Customer Name    Booking Type  \
# 0    00901ce3-3d86-4c97-bca2-40ccac2fb99f     Customer 1        Facility
# 1    b82db986-bd52-4b07-bdd8-aa8cf2016241     Customer 2  Birthday Party
# 2    6bbb6e83-9577-4f64-80b0-f073132d18f3     Customer 3  Birthday Party
# 3    f16f5beb-6a7d-4493-a19e-a30dbbd206e9     Customer 4  Birthday Party
# 4    eb297435-93d1-4e65-8dd4-6450922305cb     Customer 5           Class
# ...

# %%
df.head()
# Out:
#                              Booking ID                           Customer ID  \
# 0  279d92c6-ce26-47c0-8915-e45b77fe20e2  00901ce3-3d86-4c97-bca2-40ccac2fb99f
# 1  415bfcbe-1a2e-4d4b-809a-4c5b606653b1  b82db986-bd52-4b07-bdd8-aa8cf2016241
# 2  2100024b-46fc-47b5-ac1c-047d007a4723  6bbb6e83-9577-4f64-80b0-f073132d18f3
# 3  74936def-088f-4d34-bad1-dfa76f78b704  f16f5beb-6a7d-4493-a19e-a30dbbd206e9
# 4  6272b4e7-a508-4ed7-bae0-21f7293287a8  eb297435-93d1-4e65-8dd4-6450922305cb
#
#   Customer Name    Booking Type Booking Date     Status Class Type Instructor  \
# 0    Customer 1        Facility   30-05-2025    Pending        NaN        NaN
# 1    Customer 2  Birthday Party   29-05-2025    Pending        NaN        NaN
# 2    Customer 3  Birthday Party   09-05-2025  Confirmed        NaN        NaN
# 3    Customer 4  Birthday Party   07-06-2025    Pending        NaN        NaN
# 4    Customer 5           Class   13-04-2025    Pending        Art        NaN
#
# ...

# %% [markdown]
# ## Data cleaning process

# %%
df.isnull().sum()
# Out:
# Booking ID              0
# Customer ID             0
# Customer Name           0
# Booking Type            0
# Booking Date            0
# Status                  0
# Class Type            672
# Instructor            730
# Time Slot             205
# Duration (mins)       205
# Price                   0
# Facility              328
# Theme                 727
# Subscription Type    1000
# Service Name            0
# Service Type            0
# Customer Email         94
# Customer Phone        105
# dtype: int64

# %%
df.dropna(subset=['Class Type'],inplace=True)
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor            58
# Time Slot             66
# Duration (mins)       66
# Price                  0
# Facility             328
# Theme                328
# Subscription Type    328
# Service Name           0
# Service Type           0
# Customer Email        34
# Customer Phone        37
# dtype: int64

# %%
df.dropna(subset=['Time Slot'],inplace=True)
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor            40
# Time Slot              0
# Duration (mins)        0
# Price                  0
# Facility             262
# Theme                262
# Subscription Type    262
# Service Name           0
# Service Type           0
# Customer Email        28
# Customer Phone        28
# dtype: int64

# %%
df.dropna(subset=['Instructor'],inplace=True)
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor             0
# Time Slot              0
# Duration (mins)        0
# Price                  0
# Facility             222
# Theme                222
# Subscription Type    222
# Service Name           0
# Service Type           0
# Customer Email        21
# Customer Phone        27
# dtype: int64

# %%
df.dropna(subset=['Customer Email'],inplace=True)
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor             0
# Time Slot              0
# Duration (mins)        0
# Price                  0
# Facility             201
# Theme                201
# Subscription Type    201
# Service Name           0
# Service Type           0
# Customer Email         0
# Customer Phone        24
# dtype: int64

# %%
df.dropna(subset=['Customer Phone'],inplace=True)
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor             0
# Time Slot              0
# Duration (mins)        0
# Price                  0
# Facility             177
# Theme                177
# Subscription Type    177
# Service Name           0
# Service Type           0
# Customer Email         0
# Customer Phone         0
# dtype: int64

# %%
df.head()
# Out:
#                               Booking ID  \
# 13  74b8102e-eef6-4774-a134-5a3d0d012c3d
# 15  e8e2f341-6a4f-43b5-aee5-0b35878474cd
# 21  90662fb0-58f0-41ed-b6cf-cedaea6bc8a1
# 22  b15b65c4-2016-41ce-be0a-56b41ebaaf28
# 27  4fe3fc55-bb91-44dc-aef3-11a55c2dce53
#
#                              Customer ID Customer Name Booking Type  \
# 13  6a0d66d3-24b1-4eb5-8f6f-b9893eb57701   Customer 14        Class
# 15  489a4949-b903-4f4f-8bdb-17a0a7553d35   Customer 16        Class
# 21  9b2e9482-8e0d-40db-bc83-2da11216509c   Customer 22        Class
# 22  4934ba20-a4ef-4e8e-8a05-e4171467bea3   Customer 23        Class
# 27  a109b309-eee6-4bf1-b314-487febc058ea   Customer 28        Class
#
#    Booking Date     Status Class Type    Instructor Time Slot  \
# 13   04-06-2025    Pending        Art  Amanda Davis     16:00
# 15   10-05-2025  Confirmed        Art  Amanda Davis     10:00
# 21   20-05-2025  Confirmed      Dance  Lisa Hensley     11:00
# ...

# %%
df.drop(columns=['Subscription Type' , 'Facility','Theme'])
# Out:
#                                Booking ID  \
# 13   74b8102e-eef6-4774-a134-5a3d0d012c3d
# 15   e8e2f341-6a4f-43b5-aee5-0b35878474cd
# 21   90662fb0-58f0-41ed-b6cf-cedaea6bc8a1
# 22   b15b65c4-2016-41ce-be0a-56b41ebaaf28
# 27   4fe3fc55-bb91-44dc-aef3-11a55c2dce53
# ..                                    ...
# 981  e5267d63-19a3-4a37-8cb4-991fd5a90387
# 985  b01fa52c-b063-432e-a0fa-f457f0560624
# 992  47ed703d-5a43-4155-825f-6713a636877d
# 993  73d48a88-6115-4fed-9b4e-a42a9d392713
# 994  8ae357a5-5860-4a35-bd7a-8fc56e67f163
#
#                               Customer ID Customer Name Booking Type  \
# 13   6a0d66d3-24b1-4eb5-8f6f-b9893eb57701   Customer 14        Class
# 15   489a4949-b903-4f4f-8bdb-17a0a7553d35   Customer 16        Class
# 21   9b2e9482-8e0d-40db-bc83-2da11216509c   Customer 22        Class
# 22   4934ba20-a4ef-4e8e-8a05-e4171467bea3   Customer 23        Class
# 27   a109b309-eee6-4bf1-b314-487febc058ea   Customer 28        Class
# ...

# %%
df.shape
# Out:
# (177, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 13 to 994
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Booking ID         177 non-null    object
#  1   Customer ID        177 non-null    object
#  2   Customer Name      177 non-null    object
#  3   Booking Type       177 non-null    object
#  4   Booking Date       177 non-null    object
#  5   Status             177 non-null    object
#  6   Class Type         177 non-null    object
#  7   Instructor         177 non-null    object
#  8   Time Slot          177 non-null    object
#  9   Duration (mins)    177 non-null    float64
#  10  Price              177 non-null    float64
#  11  Facility           0 non-null      object
#  12  Theme              0 non-null      object
#  13  Subscription Type  0 non-null      float64
#  14  Service Name       177 non-null    object
#  15  Service Type       177 non-null    object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                Booking ID  \
# 13   74b8102e-eef6-4774-a134-5a3d0d012c3d
# 15   e8e2f341-6a4f-43b5-aee5-0b35878474cd
# 21   90662fb0-58f0-41ed-b6cf-cedaea6bc8a1
# 22   b15b65c4-2016-41ce-be0a-56b41ebaaf28
# 27   4fe3fc55-bb91-44dc-aef3-11a55c2dce53
# ..                                    ...
# 981  e5267d63-19a3-4a37-8cb4-991fd5a90387
# 985  b01fa52c-b063-432e-a0fa-f457f0560624
# 992  47ed703d-5a43-4155-825f-6713a636877d
# 993  73d48a88-6115-4fed-9b4e-a42a9d392713
# 994  8ae357a5-5860-4a35-bd7a-8fc56e67f163
#
#                               Customer ID Customer Name Booking Type  \
# 13   6a0d66d3-24b1-4eb5-8f6f-b9893eb57701   Customer 14        Class
# 15   489a4949-b903-4f4f-8bdb-17a0a7553d35   Customer 16        Class
# 21   9b2e9482-8e0d-40db-bc83-2da11216509c   Customer 22        Class
# 22   4934ba20-a4ef-4e8e-8a05-e4171467bea3   Customer 23        Class
# 27   a109b309-eee6-4bf1-b314-487febc058ea   Customer 28        Class
# ...

# %%
df.isnull().sum()
# Out:
# Booking ID             0
# Customer ID            0
# Customer Name          0
# Booking Type           0
# Booking Date           0
# Status                 0
# Class Type             0
# Instructor             0
# Time Slot              0
# Duration (mins)        0
# Price                  0
# Facility             177
# Theme                177
# Subscription Type    177
# Service Name           0
# Service Type           0
# Customer Email         0
# Customer Phone         0
# dtype: int64

# %% [markdown]
# ## Descriptive analysis

# %%
df.describe()
# Out:
#        Duration (mins)       Price  Subscription Type
# count       177.000000  177.000000                0.0
# mean         86.779661  134.246441                NaN
# std          29.175644   87.494374                NaN
# min          45.000000    0.000000                NaN
# 25%          45.000000   54.460000                NaN
# 50%          90.000000  124.760000                NaN
# 75%         120.000000  207.740000                NaN
# max         120.000000  298.540000                NaN

# %%
df['Customer Name'].count()
# Out:
# 177

# %% [markdown]
# ## Data visualization code

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy.stats  as stats
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'], bins= 20 , kde=True)
plt.title("Price")
plt.show()

# %% [markdown]
# ## HEATMAP

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(),annot=True, cmap = 'coolwarm', fmt = '.2f' )
plt.title("Correlation Analysis")
plt.show()
# Out:
# C:\Users\abiei\AppData\Local\Temp\ipykernel_11224\2665934856.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True, cmap = 'coolwarm', fmt = '.2f' )

# %% [markdown]
# ## Boxplot analysis

# %%
plt.figure(figsize=(8,5))
sns.boxplot( x = 'Class Type', y = 'Price', data = df )
plt.title("Box plot Analysis")
plt.show()
